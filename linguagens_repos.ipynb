# %%
import requests

# %%
print('Hello Word')
# Out:
# Hello Word

# %%
def sum(a, b):
    return a + b

result = sum(10, 10)

print(result)
# Out:
# 20

# %%
r = requests.get('https://api.github.com/events')

# %%
print(r)
# Out:
# <Response [200]>

# %%
r.status_code
# Out:
# 200

# %%
r.url
# Out:
# 'https://api.github.com/events'

# %%
r.text
# Out:
# '[{"id":"45867814157","type":"PushEvent","actor":{"id":168951753,"login":"DindaPutriFN","display_login":"DindaPutriFN","gravatar_id":"","url":"https://api.github.com/users/DindaPutriFN","avatar_url":"https://avatars.githubusercontent.com/u/168951753?"},"repo":{"id":921443474,"name":"DindaPutriFN/iguana","url":"https://api.github.com/repos/DindaPutriFN/iguana"},"payload":{"repository_id":921443474,"push_id":22288716914,"size":1,"distinct_size":1,"ref":"refs/heads/main","head":"749d7ec5364d96a2e30938bccca53ec082c333b6","before":"6b661d5b0d9a340503ffd60879c15c7ca6d40b73","commits":[{"sha":"749d7ec5364d96a2e30938bccca53ec082c333b6","author":{"email":"rerechan0202@gmail.com","name":"DindaPutriFN"},"message":"Random commit: oXNuEjgINpFHgLNoXu3Rj8KUN6ckay","distinct":true,"url":"https://api.github.com/repos/DindaPutriFN/iguana/commits/749d7ec5364d96a2e30938bccca53ec082c333b6"}]},"public":true,"created_at":"2025-01-24T01:36:14Z"},{"id":"45867814152","type":"PushEvent","actor":{"id":147053935,"login":"Marilyneb","display_login":"Marilyneb","gravatar_id":"","url":"https://api.github.com/users/Marilyneb","avatar_url":"https://avatars.githubusercontent.com/u/147053935?"},"repo":{"id":921434720,"name":"Marilyneb/Portfolio","url":"https://api.github.com/repos/Marilyneb/Portfolio"},"payload":{"repository_id":921434720,"push_id":22288716913,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"ec13097242e8a0e40f0301dca08a875e6a4a3f02","before":"37d2b58c69e0fa3cfaa67b37d9ddf7b9afac1cdb","commits":[{"sha":"ec13097242e8a0e40f0301dca08a875e6a4a3f02","author":{"email":"marilyneb@Marilynes-MacBook-Pro-3.local","name":"Marilyne Bassoulou"},"message":"update 5","distinct":true,"url":"https://api.github.com/repos/Marilyneb/Portfolio/commits/ec13097242e8a0e40f0301dca08a875e6a4a3f02"}]},"public":true,"created_at":"2025-01-24T01:36:14Z"},{"id":"45867814126","type":"PushEvent","actor":{"id":85046208,"login":"educationmoment","display_login":"educationmoment","gravatar_id":"","url":"https://api.github.com/users/educationmoment","avatar_url":"https://avatars.githubusercontent.com/u/85046208?"},"repo":{"id":853022066,"name":"chicagoedt/Lunabotics_2025","url":"https://api.github.com/repos/chicagoedt/Lunabotics_2025"},"payload":{"repository_id":853022066,"push_id":22288716966,"size":1,"distinct_size":1,"ref":"refs/heads/main","head":"f650355814f0fcf34c0470fea2a8bdd8f4a73203","before":"c3d3d580605dd48e538e8c17a9e371525e2139ae","commits":[{"sha":"f650355814f0fcf34c0470fea2a8bdd8f4a73203","author":{"email":"85046208+educationmoment@users.noreply.github.com","name":"Aakash B"},"message":"Update canable_start.sh\\n\\nno longer will it ask for an itnerface, the interface will be assumed to be can0 at all times, and it will be brought up at 1mbp/s","distinct":true,"url":"https://api.github.com/repos/chicagoedt/Lunabotics_2025/commits/f650355814f0fcf34c0470fea2a8bdd8f4a73203"}]},"public":true,"created_at":"2025-01-24T01:36:14Z","org":{"id":8107858,"login":"chicagoedt","gravatar_id":"","url":"https://api.github.com/orgs/chicagoedt","avatar_url":"https://avatars.githubusercontent.com/u/8107858?"}},{"id":"45867814143","type":"PushEvent","actor":{"id":41898282,"login":"github-actions[bot]","display_login":"github-actions","gravatar_id":"","url":"https://api.github.com/users/github-actions[bot]","avatar_url":"https://avatars.githubusercontent.com/u/41898282?"},"repo":{"id":667441126,"name":"wuban888/GREEN004","url":"https://api.github.com/repos/wuban888/GREEN004"},"payload":{"repository_id":667441126,"push_id":22288716983,"size":1,"distinct_size":1,"ref":"refs/heads/main","head":"fcc38b18a9c35fd7a09e207b766ff3963285ff70","before":"1657be088d9ef6a3a0b52efa926fecf4940d9b13","commits":[{"sha":"fcc38b18a9c35fd7a09e207b766ff3963285ff70","author":{"email":"wuban888@gmail.com","name":"wuban888"},"message":"a commit a day keeps your girlfriend away","distinct":true,"url":"https://api.github.com/repos/wuban888/GREEN004/commits/fcc38b18a9c35fd7a09e207b766ff3963285ff70"}]},"pu ...

# %%
r.json()
# Out:
# [{'id': '45867814157',
#   'type': 'PushEvent',
#   'actor': {'id': 168951753,
#    'login': 'DindaPutriFN',
#    'display_login': 'DindaPutriFN',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/DindaPutriFN',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/168951753?'},
#   'repo': {'id': 921443474,
#    'name': 'DindaPutriFN/iguana',
#    'url': 'https://api.github.com/repos/DindaPutriFN/iguana'},
#   'payload': {'repository_id': 921443474,
#    'push_id': 22288716914,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '749d7ec5364d96a2e30938bccca53ec082c333b6',
#    'before': '6b661d5b0d9a340503ffd60879c15c7ca6d40b73',
#    'commits': [{'sha': '749d7ec5364d96a2e30938bccca53ec082c333b6',
#      'author': {'email': 'rerechan0202@gmail.com', 'name': 'DindaPutriFN'},
#      'message': 'Random commit: oXNuEjgINpFHgLNoXu3Rj8KUN6ckay',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/DindaPutriFN/iguana/commits/749d7ec5364d96a2e30938bccca53ec082c333b6'}]},
#   'public': True,
#   'created_at': '2025-01-24T01:36:14Z'},
#  {'id': '45867814152',
#   'type': 'PushEvent',
#   'actor': {'id': 147053935,
#    'login': 'Marilyneb',
#    'display_login': 'Marilyneb',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Marilyneb',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/147053935?'},
#   'repo': {'id': 921434720,
#    'name': 'Marilyneb/Portfolio',
#    'url': 'https://api.github.com/repos/Marilyneb/Portfolio'},
#   'payload': {'repository_id': 921434720,
#    'push_id': 22288716913,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'ec13097242e8a0e40f0301dca08a875e6a4a3f02',
#    'before': '37d2b58c69e0fa3cfaa67b37d9ddf7b9afac1cdb',
#    'commits': [{'sha': 'ec13097242e8a0e40f0301dca08a875e6a4a3f02',
#      'author': {'email': 'marilyneb@Marilynes-MacBook-Pro-3.local',
#       'name': 'Marilyne Bassoulou'},
#      'message': 'update 5',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Marilyneb/Portfolio/commits/ec13097242e8a0e40f0301dca08a875e6a4a3f02'}]},
#   'public': True,
#   'created_at': '2025-01-24T01:36:14Z'},
#  {'id': '45867814126',
#   'type': 'PushEvent',
#   'actor': {'id': 85046208,
#    'login': 'educationmoment',
#    'display_login': 'educationmoment',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/educationmoment',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/85046208?'},
#   'repo': {'id': 853022066,
#    'name': 'chicagoedt/Lunabotics_2025',
#    'url': 'https://api.github.com/repos/chicagoedt/Lunabotics_2025'},
#   'payload': {'repository_id': 853022066,
#    'push_id': 22288716966,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'f650355814f0fcf34c0470fea2a8bdd8f4a73203',
#    'before': 'c3d3d580605dd48e538e8c17a9e371525e2139ae',
#    'commits': [{'sha': 'f650355814f0fcf34c0470fea2a8bdd8f4a73203',
#      'author': {'email': '85046208+educationmoment@users.noreply.github.com',
#       'name': 'Aakash B'},
#      'message': 'Update canable_start.sh\n\nno longer will it ask for an itnerface, the interface will be assumed to be can0 at all times, and it will be brought up at 1mbp/s',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/chicagoedt/Lunabotics_2025/commits/f650355814f0fcf34c0470fea2a8bdd8f4a73203'}]},
#   'public': True,
#   'created_at': '2025-01-24T01:36:14Z',
#   'org': {'id': 8107858,
#    'login': 'chicagoedt',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/chicagoedt',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8107858?'}},
#  {'id': '45867814143',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 667441126,
#    'name': 'wuban888/GREEN004',
#    'url': 'https://api.github.com/repos/wuban888/GREEN004'},
#   'payload': {'repository_id': 667441126,
#    'push_id': 22288716983,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'fcc38b18a9c35fd7a09e207b766ff3963285ff70',
#    'before': '1657be088d9ef6a3a0b52efa926fecf4940d9b13',
#    'commits': [{'sha': 'fcc38b18a9c35fd7a09e207b766ff3963285ff70',
#      'author': {'email': 'wuban888@gmail.com', 'name': 'wuban888'},
#      'message': 'a commit a day keeps your girlfriend away',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/wuban888/GREEN004/commits/fcc38b18a9c35fd7a09e207b766ff3963285ff70'}]},
#   'public': True,
#   'created_at': '2025-01-24T01:36:14Z'},
#  {'id': '45867814115',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 324498964,
#    'name': 'renceInbox/renceInbox',
#    'url': 'https://api.github.com/repos/renceInbox/renceInbox'},
#   'payload': {'repository_id': 324498964,
#    'push_id': 22288716954,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '3ec5ba244bf5d42bb9d8bac1b0e03565123244a8',
#    'before': 'c79532116a225a97440662a1eb276d7abc6f2dd6',
#    'commits': [{'sha': '3ec5ba244bf5d42bb9d8bac1b0e03565123244a8',
#      'author': {'email': '41898282+github-actions[bot]@users.noreply.github.com',
#       'name': 'github-actions[bot]'},
#      'message': 'Update github-metrics.svg - [Skip GitHub Action]',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/renceInbox/renceInbox/commits/3ec5ba244bf5d42bb9d8bac1b0e03565123244a8'}]},
#   'public': True,
#   'created_at': '2025-01-24T01:36:14Z'},
#  {'id': '45867814136',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 531892631,
#    'name': 'CAKeysama/CAkeysama',
#    'url': 'https://api.github.com/repos/CAKeysama/CAkeysama'},
#   'payload': {'repository_id': 531892631,
#    'push_id': 22288716976,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/output',
#    'head': '20b435c46c9e13058032e671c0d4e662fa8c2c35',
#    'before': '9d96010a3b2465727fd6b83471fd6b83aa47bbba',
#    'commits': [{'sha': '20b435c46c9e13058032e671c0d4e662fa8c2c35',
#      'author': {'email': '41898282+github-actions[bot]@users.noreply.github.com',
#       'name': 'github-actions[bot]'},
#      'message': 'Deploy to GitHub pages',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/CAKeysama/CAkeysama/commits/20b435c46c9e13058032e671c0d4e662fa8c2c35'}]},
#   'public': True,
#   'created_at': '2025-01-24T01:36:14Z'},
#  {'id': '45867814120',
#   'type': 'PushEvent',
#   'actor': {'id': 119495800,
#    'login': 'ftalfp',
#    'display_login': 'ftalfp',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ftalfp',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/119495800?'},
#   'repo': {'id': 830729303,
#    'name': 'fin-track/upptime',
#    'url': 'https://api.github.com/repos/fin-track/upptime'},
#   'payload': {'repository_id': 830729303,
#    'push_id': 22288716906,
#    'size': 2,
#    'distinct_size': 2,
#    'ref': 'refs/heads/master',
#    'head': '4ae7de613ea155f6b6ee193ac45f944a459af8d9',
#    'before': '85aec080d493840d3f47abaf1c886f9cf986f7f6',
#    'commits': [{'sha': '87f1c66448ca176a79ace14e87d62605311be878',
#      'author': {'email': '73812536+upptime-bot@users.noreply.github.com',
#       'name': 'Upptime Bot'},
#      'message': ':pencil: Update summary in README [skip ci] [upptime]',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/fin-track/upptime/commits/87f1c66448ca176a79ace14e87d62605311be878'},
#     {'sha': '4ae7de613ea155f6b6ee193ac45f944a459af8d9',
#      'author': {'email': '73812536+upptime-bot@users.noreply.github.com',
#       'name': 'Upptime Bot'},
#      'message': ':card_file_box: Update status summary [skip ci] [upptime]',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/fin-track/upptime/commits/4ae7de613ea155f6b6ee193ac45f944a459af8d9'}]},
#   'public': True,
#   'created_at': '2025-01-24T01:36:14Z',
#   'org': {'id': 109149234,
#    'login': 'fin-track',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/fin-track',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/109149234?'}},
#  {'id': '45867814130',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 49699333,
#    'login': 'dependabot[bot]',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'},
#   'repo': {'id': 712846590,
#    'name': 'Geonovum-labs/ogc-checker',
#    'url': 'https://api.github.com/repos/Geonovum-labs/ogc-checker'},
#   'payload': {'action': 'opened',
#    'number': 284,
#    'pull_request': {'url': 'https://api.github.com/repos/Geonovum-labs/ogc-checker/pulls/284',
#     'id': 2295746875,
#     'node_id': 'PR_kwDOKn0s_s6I1lE7',
#     'html_url': 'https://github.com/Geonovum-labs/ogc-checker/pull/284',
#     'diff_url': 'https://github.com/Geonovum-labs/ogc-checker/pull/284.diff',
#     'patch_url': 'https://github.com/Geonovum-labs/ogc-checker/pull/284.patch',
#     'issue_url': 'https://api.github.com/repos/Geonovum-labs/ogc-checker/issues/284',
#     'number': 284,
#     'state': 'open',
#     'locked': False,
#     'title': 'Bump vitest from 3.0.3 to 3.0.4',
#     'user': {'login': 'dependabot[bot]',
#      'id': 49699333,
#      'node_id': 'MDM6Qm90NDk2OTkzMzM=',
#      'avatar_url': 'https://avatars.githubusercontent.com/in/29110?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/dependabot%5Bbot%5D',
#      'html_url': 'https://github.com/apps/dependabot',
#      'followers_url': 'https://api.github.com/users/dependabot%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/dependabot%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/dependabot%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/dependabot%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/dependabot%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/dependabot%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/dependabot%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'user_view_type': 'public',
#      'site_admin': False},
#     'body': 'Bumps [vitest](https://github.com/vitest-dev/vitest/tree/HEAD/packages/vitest) from 3.0.3 to 3.0.4.\n<details>\n<summary>Release notes</summary>\n<p><em>Sourced from <a href="https://github.com/vitest-dev/vitest/releases">vitest\'s releases</a>.</em></p>\n<blockquote>\n<h2>v3.0.4</h2>\n<h3>\xa0\xa0\xa0🐞 Bug Fixes</h3>\n<ul>\n<li>Filter projects eagerly during config resolution \xa0-\xa0 by <a href="https://github.com/sheremet-va"><code>@\u200bsheremet-va</code></a> and <a href="https://github.com/AriPerkkio"><code>@\u200bAriPerkkio</code></a> in <a href="https://redirect.github.com/vitest-dev/vitest/issues/7313">vitest-dev/vitest#7313</a> <a href="https://github.com/vitest-dev/vitest/commit/dff4406d"><!-- raw HTML omitted -->(dff44)<!-- raw HTML omitted --></a></li>\n<li>Apply <code>development|production</code> condition on Vites 6 by <a href="https://github.com/hi-ogawa"><code>@\u200bhi-ogawa</code></a> and <a href="https://github.com/sheremet-va"><code>@\u200bsheremet-va</code></a> (<a href="https://github.com/vitest-dev/vitest/tree/HEAD/packages/vitest/issues/7301">#7301</a>) <a href="https://github.com/vitest-dev/vitest/commit/ef1464fc7b101709bfbf7b040e5bad62998c2ff9"><!-- raw HTML omitted -->(ef146)<!-- raw HTML omitted --></a></li>\n<li><strong>browser</strong>: Restrict served files from <code>/__screenshot-error</code> \xa0-\xa0 by <a href="https://github.com/hi-ogawa"><code>@\u200bhi-ogawa</code></a> in <a href="https://redirect.github.com/vitest-dev/vitest/issues/7340">vitest-dev/vitest#7340</a> <a href="https://github.com/vitest-dev/vitest/commit/ed9aeba2"><!-- raw HTML omitted -->(ed9ae)<!-- raw HTML omitted --></a></li>\n<li><strong>deps</strong>: Update all non-major dependencies \xa0-\xa0 by <a href="https://github.com/sheremet-va"><code>@\u200bsheremet-va</code></a> in <a href="https://redirect.github.com/vitest-dev/vitest/issues/7297">vitest-dev/vitest#7297</a> <a href="https://github.com/vitest-dev/vitest/commit/38ea8eae"><!-- raw HTML omitted -->(38ea8)<!-- raw HTML omitted --></a></li>\n<li><strong>runner</strong>: Timeout long sync hook \xa0-\xa0 by <a href="https://github.com/hi-ogawa"><code>@\u200bhi-ogawa</code></a> in <a href="https://redirect.github.com/vitest-dev/vitest/issues/7289">vitest-dev/vitest#7289</a> <a href="https://github.com/vitest-dev/vitest/commit/c60ee27c"><!-- raw HTML omitted -->(c60ee)<!-- raw HTML omitted --></a></li>\n<li><strong>typechecking</strong>: Support typechecking parsing with Vite 6 \xa0-\xa0 by <a href="https://github.com/sheremet-va"><code>@\u200bsheremet-va</code></a> in <a href="https://redirect.github.com/vitest-dev/vitest/issues/7335">vitest-dev/vitest#7335</a> <a href="https://github.com/vitest-dev/vitest/commit/bff70be9"><!-- raw HTML omitted -->(bff70)<!-- raw HTML omitted --></a></li>\n<li><strong>types</strong>: Fix public types \xa0-\xa0 by <a href="https://github.com/mrginglymus"><code>@\u200bmrginglymus</code></a> and <a href="https://github.com/sheremet-va"><code>@\u200bsheremet-va</code></a> in <a href="https://redirect.github.com/vitest-dev/vitest/issues/7328">vitest-dev/vitest#7328</a> <a href="https://github.com/vitest-dev/vitest/commit/ce6af70c"><!-- raw HTML omitted -->(ce6af)<!-- raw HTML omitted --></a></li>\n</ul>\n<h5>\xa0\xa0\xa0\xa0<a href="https://github.com/vitest-dev/vitest/compare/v3.0.3...v3.0.4">View changes on GitHub</a></h5>\n</blockquote>\n</details>\n<details>\n<summary>Commits</summary>\n<ul>\n<li><a href="https://github.com/vitest-dev/vitest/commit/9e404375825d870ed9d90db854d96f77a7abeaff"><code>9e40437</code></a> chore: release v3.0.4</li>\n<li><a href="https://github.com/vitest-dev/vitest/commit/ef1464fc7b101709bfbf7b040e5bad62998c2ff9"><code>ef1464f</code></a> fix: apply <code>development|production</code> condition on Vite 6 (<a href="https://github.com/vitest-dev/vitest/tree/HEAD/packages/vitest/issues/7301">#7301</a>)</li>\n<li><a href="https://github.com/vitest-dev/vitest/commit/38ea8eaef86f808a4c088f7439d138458 ...
#     'created_at': '2025-01-24T01:36:12Z',
#     'updated_at': '2025-01-24T01:36:13Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': '325647b30d83a6b12eab9f0787d3d7d13ad0cf07',
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [{'id': 6618576857,
#       'node_id': 'LA_kwDOKn0s_s8AAAABin932Q',
#       'url': 'https://api.github.com/repos/Geonovum-labs/ogc-checker/labels/dependencies',
#       'name': 'dependencies',
#       'color': '0366d6',
#       'default': False,
#       'description': 'Pull requests that update a dependency file'}],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/Geonovum-labs/ogc-checker/pulls/284/commits',
#     'review_comments_url': 'https://api.github.com/repos/Geonovum-labs/ogc-checker/pulls/284/comments',
#     'review_comment_url': 'https://api.github.com/repos/Geonovum-labs/ogc-checker/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/Geonovum-labs/ogc-checker/issues/284/comments',
#     'statuses_url': 'https://api.github.com/repos/Geonovum-labs/ogc-checker/statuses/28ce5bcb53fac93c443488067566c743b9c8a47b',
#     'head': {'label': 'Geonovum-labs:dependabot/npm_and_yarn/vitest-3.0.4',
#      'ref': 'dependabot/npm_and_yarn/vitest-3.0.4',
#      'sha': '28ce5bcb53fac93c443488067566c743b9c8a47b',
#      'user': {'login': 'Geonovum-labs',
#       'id': 149525723,
#       'node_id': 'O_kgDOCOmU2w',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/149525723?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/Geonovum-labs',
#       'html_url': 'https://github.com/Geonovum-labs',
#       'followers_url': 'https://api.github.com/users/Geonovum-labs/followers',
#       'following_url': 'https://api.github.com/users/Geonovum-labs/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/Geonovum-labs/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/Geonovum-labs/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/Geonovum-labs/subscriptions',
#       'organizations_url': 'https://api.github.com/users/Geonovum-labs/orgs',
#       'repos_url': 'https://api.github.com/users/Geonovum-labs/repos',
#       'events_url': 'https://api.github.com/users/Geonovum-labs/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/Geonovum-labs/received_events',
#       'type': 'Organization',
#       'user_view_type': 'public',
#       'site_admin': False},
#      'repo': {'id': 712846590,
#       'node_id': 'R_kgDOKn0s_g',
#       'name': 'ogc-checker',
#       'full_name': 'Geonovum-labs/ogc-checker',
#       'private': False,
#       'owner': {'login': 'Geonovum-labs',
#        'id': 149525723,
#        'node_id': 'O_kgDOCOmU2w',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/149525723?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/Geonovum-labs',
#        'html_url': 'https://github.com/Geonovum-labs',
#        'followers_url': 'https://api.github.com/users/Geonovum-labs/followers',
#        'following_url': 'https://api.github.com/users/Geonovum-labs/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/Geonovum-labs/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/Geonovum-labs/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/Geonovum-labs/subscriptions',
#        'organizations_url': 'https://api.github.com/users/Geonovum-labs/orgs',
#        'repos_url': 'https://api.github.com/users/Geonovum-labs/repos',
#        'events_url': 'https://api.github.com/users/Geonovum-labs/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/Geonovum-labs/received_events',
#        'type': 'Organization',
#        'user_view_type': 'public',
#        'site_admin': False},
#       'html_url': 'https://github.com/Geonovum-labs/ogc-checker',
#       'description': 'This repository contains the Geonovum checker (validation & linting) for OGC API Standards and OGC Features and Geometries JSON (JSON-FG).',
#       'fork': False,
#       'url': 'https://api.github.com/repos/Geonovum-labs/ogc-checker',
#       'forks_url': 'https://api.github.com/repos/Geonovum-labs/ogc-checker/forks',
#       'keys_url': 'https://api.github.com/repos/Geonovum-labs/ogc-checker/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/Geonovum-labs/ogc-checker/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/Geonovum-labs/ogc-checker/teams',
#       'hooks_url': 'https://api.github.com/repos/Geonovum-labs/ogc-checker/hooks',
#       'issue_events_url': 'https://api.github.com/repos/Geonovum-labs/ogc-checker/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/Geonovum-labs/ogc-checker/events',
#       'assignees_url': 'https://api.github.com/repos/Geonovum-labs/ogc-checker/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/Geonovum-labs/ogc-checker/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/Geonovum-labs/ogc-checker/tags',
#       'blobs_url': 'https://api.github.com/repos/Geonovum-labs/ogc-checker/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/Geonovum-labs/ogc-checker/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/Geonovum-labs/ogc-checker/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/Geonovum-labs/ogc-checker/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/Geonovum-labs/ogc-checker/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/Geonovum-labs/ogc-checker/languages',
#       'stargazers_url': 'https://api.github.com/repos/Geonovum-labs/ogc-checker/stargazers',
#       'contributors_url': 'https://api.github.com/repos/Geonovum-labs/ogc-checker/contributors',
#       'subscribers_url': 'https://api.github.com/repos/Geonovum-labs/ogc-checker/subscribers',
#       'subscription_url': 'https://api.github.com/repos/Geonovum-labs/ogc-checker/subscription',
#       'commits_url': 'https://api.github.com/repos/Geonovum-labs/ogc-checker/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/Geonovum-labs/ogc-checker/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/Geonovum-labs/ogc-checker/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/Geonovum-labs/ogc-checker/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/Geonovum-labs/ogc-checker/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/Geonovum-labs/ogc-checker/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/Geonovum-labs/ogc-checker/merges',
#       'archive_url': 'https://api.github.com/repos/Geonovum-labs/ogc-checker/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/Geonovum-labs/ogc-checker/downloads',
#       'issues_url': 'https://api.github.com/repos/Geonovum-labs/ogc-checker/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/Geonovum-labs/ogc-checker/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/Geonovum-labs/ogc-checker/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/Geonovum-labs/ogc-checker/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/Geonovum-labs/ogc-checker/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/Geonovum-labs/ogc-checker/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/Geonovum-labs/ogc-checker/deployments',
#       'created_at': '2023-11-01T10:17:47Z',
#       'updated_at': '2025-01-22T07:25:56Z',
#       'pushed_at': '2025-01-24T01:36:11Z',
#       'git_url': 'git://github.com/Geonovum-labs/ogc-checker.git',
#       'ssh_url': 'git@github.com:Geonovum-labs/ogc-checker.git',
#       'clone_url': 'https://github.com/Geonovum-labs/ogc-checker.git',
#       'svn_url': 'https://github.com/Geonovum-labs/ogc-checker',
#       'homepage': 'https://geonovum-labs.github.io/ogc-checker/',
#       'size': 11843,
#       'stargazers_count': 3,
#       'watchers_count': 3,
#       'language': 'TypeScript',
#       'has_issues': True,
#       'has_projects': False,
#       'has_downloads': True,
#       'has_wiki': False,
#       'has_pages': True,
#       'has_discussions': False,
#       'forks_count': 1,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 10,
#       'license': {'key': 'mit',
#        'name': 'MIT License',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit',
#        'node_id': 'MDc6TGljZW5zZTEz'},
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 1,
#       'open_issues': 10,
#       'watchers': 3,
#       'default_branch': 'main'}},
#     'base': {'label': 'Geonovum-labs:main',
#      'ref': 'main',
#      'sha': '6cee9f6a1ccf6facfb6c89bb2d2899e69f3efb4d',
#      'user': {'login': 'Geonovum-labs',
#       'id': 149525723,
#       'node_id': 'O_kgDOCOmU2w',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/149525723?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/Geonovum-labs',
#       'html_url': 'https://github.com/Geonovum-labs',
#       'followers_url': 'https://api.github.com/users/Geonovum-labs/followers',
#       'following_url': 'https://api.github.com/users/Geonovum-labs/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/Geonovum-labs/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/Geonovum-labs/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/Geonovum-labs/subscriptions',
#       'organizations_url': 'https://api.github.com/users/Geonovum-labs/orgs',
#       'repos_url': 'https://api.github.com/users/Geonovum-labs/repos',
#       'events_url': 'https://api.github.com/users/Geonovum-labs/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/Geonovum-labs/received_events',
#       'type': 'Organization',
#       'user_view_type': 'public',
#       'site_admin': False},
#      'repo': {'id': 712846590,
#       'node_id': 'R_kgDOKn0s_g',
#       'name': 'ogc-checker',
#       'full_name': 'Geonovum-labs/ogc-checker',
#       'private': False,
#       'owner': {'login': 'Geonovum-labs',
#        'id': 149525723,
#        'node_id': 'O_kgDOCOmU2w',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/149525723?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/Geonovum-labs',
#        'html_url': 'https://github.com/Geonovum-labs',
#        'followers_url': 'https://api.github.com/users/Geonovum-labs/followers',
#        'following_url': 'https://api.github.com/users/Geonovum-labs/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/Geonovum-labs/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/Geonovum-labs/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/Geonovum-labs/subscriptions',
#        'organizations_url': 'https://api.github.com/users/Geonovum-labs/orgs',
#        'repos_url': 'https://api.github.com/users/Geonovum-labs/repos',
#        'events_url': 'https://api.github.com/users/Geonovum-labs/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/Geonovum-labs/received_events',
#        'type': 'Organization',
#        'user_view_type': 'public',
#        'site_admin': False},
#       'html_url': 'https://github.com/Geonovum-labs/ogc-checker',
#       'description': 'This repository contains the Geonovum checker (validation & linting) for OGC API Standards and OGC Features and Geometries JSON (JSON-FG).',
#       'fork': False,
#       'url': 'https://api.github.com/repos/Geonovum-labs/ogc-checker',
#       'forks_url': 'https://api.github.com/repos/Geonovum-labs/ogc-checker/forks',
#       'keys_url': 'https://api.github.com/repos/Geonovum-labs/ogc-checker/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/Geonovum-labs/ogc-checker/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/Geonovum-labs/ogc-checker/teams',
#       'hooks_url': 'https://api.github.com/repos/Geonovum-labs/ogc-checker/hooks',
#       'issue_events_url': 'https://api.github.com/repos/Geonovum-labs/ogc-checker/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/Geonovum-labs/ogc-checker/events',
#       'assignees_url': 'https://api.github.com/repos/Geonovum-labs/ogc-checker/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/Geonovum-labs/ogc-checker/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/Geonovum-labs/ogc-checker/tags',
#       'blobs_url': 'https://api.github.com/repos/Geonovum-labs/ogc-checker/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/Geonovum-labs/ogc-checker/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/Geonovum-labs/ogc-checker/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/Geonovum-labs/ogc-checker/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/Geonovum-labs/ogc-checker/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/Geonovum-labs/ogc-checker/languages',
#       'stargazers_url': 'https://api.github.com/repos/Geonovum-labs/ogc-checker/stargazers',
#       'contributors_url': 'https://api.github.com/repos/Geonovum-labs/ogc-checker/contributors',
#       'subscribers_url': 'https://api.github.com/repos/Geonovum-labs/ogc-checker/subscribers',
#       'subscription_url': 'https://api.github.com/repos/Geonovum-labs/ogc-checker/subscription',
#       'commits_url': 'https://api.github.com/repos/Geonovum-labs/ogc-checker/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/Geonovum-labs/ogc-checker/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/Geonovum-labs/ogc-checker/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/Geonovum-labs/ogc-checker/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/Geonovum-labs/ogc-checker/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/Geonovum-labs/ogc-checker/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/Geonovum-labs/ogc-checker/merges',
#       'archive_url': 'https://api.github.com/repos/Geonovum-labs/ogc-checker/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/Geonovum-labs/ogc-checker/downloads',
#       'issues_url': 'https://api.github.com/repos/Geonovum-labs/ogc-checker/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/Geonovum-labs/ogc-checker/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/Geonovum-labs/ogc-checker/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/Geonovum-labs/ogc-checker/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/Geonovum-labs/ogc-checker/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/Geonovum-labs/ogc-checker/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/Geonovum-labs/ogc-checker/deployments',
#       'created_at': '2023-11-01T10:17:47Z',
#       'updated_at': '2025-01-22T07:25:56Z',
#       'pushed_at': '2025-01-24T01:36:11Z',
#       'git_url': 'git://github.com/Geonovum-labs/ogc-checker.git',
#       'ssh_url': 'git@github.com:Geonovum-labs/ogc-checker.git',
#       'clone_url': 'https://github.com/Geonovum-labs/ogc-checker.git',
#       'svn_url': 'https://github.com/Geonovum-labs/ogc-checker',
#       'homepage': 'https://geonovum-labs.github.io/ogc-checker/',
#       'size': 11843,
#       'stargazers_count': 3,
#       'watchers_count': 3,
#       'language': 'TypeScript',
#       'has_issues': True,
#       'has_projects': False,
#       'has_downloads': True,
#       'has_wiki': False,
#       'has_pages': True,
#       'has_discussions': False,
#       'forks_count': 1,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 10,
#       'license': {'key': 'mit',
#        'name': 'MIT License',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit',
#        'node_id': 'MDc6TGljZW5zZTEz'},
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 1,
#       'open_issues': 10,
#       'watchers': 3,
#       'default_branch': 'main'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/Geonovum-labs/ogc-checker/pulls/284'},
#      'html': {'href': 'https://github.com/Geonovum-labs/ogc-checker/pull/284'},
#      'issue': {'href': 'https://api.github.com/repos/Geonovum-labs/ogc-checker/issues/284'},
#      'comments': {'href': 'https://api.github.com/repos/Geonovum-labs/ogc-checker/issues/284/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/Geonovum-labs/ogc-checker/pulls/284/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/Geonovum-labs/ogc-checker/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/Geonovum-labs/ogc-checker/pulls/284/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/Geonovum-labs/ogc-checker/statuses/28ce5bcb53fac93c443488067566c743b9c8a47b'}},
#     'author_association': 'CONTRIBUTOR',
#     'auto_merge': None,
#     'active_lock_reason': None,
#     'merged': False,
#     'mergeable': True,
#     'rebaseable': True,
#     'mergeable_state': 'clean',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 53,
#     'deletions': 49,
#     'changed_files': 2}},
#   'public': True,
#   'created_at': '2025-01-24T01:36:14Z',
#   'org': {'id': 149525723,
#    'login': 'Geonovum-labs',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/Geonovum-labs',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/149525723?'}},
#  {'id': '45867814106',
#   'type': 'PushEvent',
#   'actor': {'id': 13872653,
#    'login': 'mmguero',
#    'display_login': 'mmguero',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mmguero',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/13872653?'},
#   'repo': {'id': 384151164,
#    'name': 'idaholab/repository-statistics',
#    'url': 'https://api.github.com/repos/idaholab/repository-statistics'},
#   'payload': {'repository_id': 384151164,
#    'push_id': 22288716953,
#    'size': 3,
#    'distinct_size': 3,
#    'ref': 'refs/heads/main',
#    'head': 'bd05bd83e3a6b00fc639844f335f2d9f8d715651',
#    'before': '69029a20d996c4d0c90e853c6c9f91e686aa922f',
#    'commits': [{'sha': 'adfeb67ffecc8b0603025f30c0bb38acdd4e4450',
#      'author': {'email': 'action@github.com', 'name': 'GitHub Action'},
#      'message': 'ghrs: snap 01-24-0126-B189 for cisagov/icsnpp-dnp3',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/idaholab/repository-statistics/commits/adfeb67ffecc8b0603025f30c0bb38acdd4e4450'},
#     {'sha': '5fe6347aac3f631533fa958888926ceaf3de330c',
#      'author': {'email': 'action@github.com', 'name': 'GitHub Action'},
#      'message': 'ghrs: vc agg 01-24-0126-B189 for cisagov/icsnpp-dnp3',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/idaholab/repository-statistics/commits/5fe6347aac3f631533fa958888926ceaf3de330c'},
#     {'sha': 'bd05bd83e3a6b00fc639844f335f2d9f8d715651',
#      'author': {'email': 'action@github.com', 'name': 'GitHub Action'},
#      'message': 'ghrs: report 01-24-0126-B189 for cisagov/icsnpp-dnp3',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/idaholab/repository-statistics/commits/bd05bd83e3a6b00fc639844f335f2d9f8d715651'}]},
#   'public': True,
#   'created_at': '2025-01-24T01:36:14Z',
#   'org': {'id': 3855370,
#    'login': 'idaholab',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/idaholab',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/3855370?'}},
#  {'id': '45867814104',
#   'type': 'PushEvent',
#   'actor': {'id': 102863074,
#    'login': 'AnhNangCuaEm',
#    'display_login': 'AnhNangCuaEm',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/AnhNangCuaEm',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/102863074?'},
#   'repo': {'id': 880746459,
#    'name': 'AnhNangCuaEm/GREENSPACE',
#    'url': 'https://api.github.com/repos/AnhNangCuaEm/GREENSPACE'},
#   'payload': {'repository_id': 880746459,
#    'push_id': 22288716931,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '6e51c5675bbc69aea128b89f5687addad1f65c0c',
#    'before': '6b4a85846cd9afc981394cd50f9f586430cfb154',
#    'commits': [{'sha': '6e51c5675bbc69aea128b89f5687addad1f65c0c',
#      'author': {'email': '102863074+AnhNangCuaEm@users.noreply.github.com',
#       'name': 'AnhNangCuaEm'},
#      'message': 'add layout dashboard and change device distribution from card to chart',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/AnhNangCuaEm/GREENSPACE/commits/6e51c5675bbc69aea128b89f5687addad1f65c0c'}]},
#   'public': True,
#   'created_at': '2025-01-24T01:36:14Z'},
#  {'id': '45867814098',
#   'type': 'PushEvent',
#   'actor': {'id': 80158828,
#    'login': 'elouannh',
#    'display_login': 'elouannh',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/elouannh',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/80158828?'},
#   'repo': {'id': 364312226,
#    'name': 'elouannh/elouannh',
#    'url': 'https://api.github.com/repos/elouannh/elouannh'},
#   'payload': {'repository_id': 364312226,
#    'push_id': 22288716969,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '4d4e61d72d17b124ae6459ec2c71cacf64de9e53',
#    'before': 'e09b657a9d9591f2fa322ce958eb93c806f25190',
#    'commits': [{'sha': '4d4e61d72d17b124ae6459ec2c71cacf64de9e53',
#      'author': {'email': '41898282+github-actions[bot]@users.noreply.github.com',
#       'name': 'readme-bot'},
#      'message': 'Updated with Dev Metrics',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/elouannh/elouannh/commits/4d4e61d72d17b124ae6459ec2c71cacf64de9e53'}]},
#   'public': True,
#   'created_at': '2025-01-24T01:36:14Z'},
#  {'id': '45867814060',
#   'type': 'PushEvent',
#   'actor': {'id': 44130236,
#    'login': 'kingking888',
#    'display_login': 'kingking888',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/kingking888',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/44130236?'},
#   'repo': {'id': 920373667,
#    'name': 'kingking888/X1a0HeWeChatPlugin',
#    'url': 'https://api.github.com/repos/kingking888/X1a0HeWeChatPlugin'},
#   'payload': {'repository_id': 920373667,
#    'push_id': 22288716937,
#    'size': 2,
#    'distinct_size': 2,
#    'ref': 'refs/heads/main',
#    'head': '3a41b6dcbafcfa5e8d88de445e8e94228353e148',
#    'before': '84570731a0571e8112cde9ab18369c1eec017920',
#    'commits': [{'sha': '08711e625c49e3b5eb50a93de55ab31f7eeac8cd',
#      'author': {'email': 'x1a0he@outlook.com', 'name': 'X1a0He'},
#      'message': 'fix: 修复了开关毛玻璃模式崩溃的问题\n\n- install.sh 脚本增加了删除旧的插件配置\n- 调整了强制深色模式的特性\n- 调整了部分配置项的默认值，现在微信多开功能和毛玻璃模式默认为不开启\n- 调整部分菜单栏状态切换时的提示',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/kingking888/X1a0HeWeChatPlugin/commits/08711e625c49e3b5eb50a93de55ab31f7eeac8cd'},
#     {'sha': '3a41b6dcbafcfa5e8d88de445e8e94228353e148',
#      'author': {'email': 'x1a0he@outlook.com', 'name': 'X1a0He'},
#      'message': 'docs: README.md 添加 Star History',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/kingking888/X1a0HeWeChatPlugin/commits/3a41b6dcbafcfa5e8d88de445e8e94228353e148'}]},
#   'public': True,
#   'created_at': '2025-01-24T01:36:14Z'},
#  {'id': '45867814117',
#   'type': 'CreateEvent',
#   'actor': {'id': 148491184,
#    'login': 'kichboy1992',
#    'display_login': 'kichboy1992',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/kichboy1992',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/148491184?'},
#   'repo': {'id': 921458900,
#    'name': 'kichboy1992/mayao',
#    'url': 'https://api.github.com/repos/kichboy1992/mayao'},
#   'payload': {'ref': 'main',
#    'ref_type': 'branch',
#    'master_branch': 'main',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2025-01-24T01:36:14Z'},
#  {'id': '45867814094',
#   'type': 'PushEvent',
#   'actor': {'id': 94942855,
#    'login': 'jasonjayoo',
#    'display_login': 'jasonjayoo',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jasonjayoo',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/94942855?'},
#   'repo': {'id': 487677825,
#    'name': 'jasonjayoo/jasonyoo-fullstack-portfolio',
#    'url': 'https://api.github.com/repos/jasonjayoo/jasonyoo-fullstack-portfolio'},
#   'payload': {'repository_id': 487677825,
#    'push_id': 22288716971,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'c86777a773db44ad7c0a937197af8102645988e8',
#    'before': 'cc254e43a5025856c9d5813482cd78d95935f248',
#    'commits': [{'sha': 'c86777a773db44ad7c0a937197af8102645988e8',
#      'author': {'email': '94942855+jasonjayoo@users.noreply.github.com',
#       'name': 'jasonjayoo'},
#      'message': 'updating entire site',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/jasonjayoo/jasonyoo-fullstack-portfolio/commits/c86777a773db44ad7c0a937197af8102645988e8'}]},
#   'public': True,
#   'created_at': '2025-01-24T01:36:14Z'},
#  {'id': '45867814086',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 657148175,
#    'name': 'GersonHeluka/GersonHeluka',
#    'url': 'https://api.github.com/repos/GersonHeluka/GersonHeluka'},
#   'payload': {'repository_id': 657148175,
#    'push_id': 22288716957,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '17a70825952aaf65aade681c45a4fb6a4b3a9f51',
#    'before': '03b6fef264cb41c4b6dfac3e49f0bacf84733ef5',
#    'commits': [{'sha': '17a70825952aaf65aade681c45a4fb6a4b3a9f51',
#      'author': {'email': 'yanashilova759@gmail.com', 'name': 'GersonHeluka'},
#      'message': 'a commit a day keeps your girlfriend away',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/GersonHeluka/GersonHeluka/commits/17a70825952aaf65aade681c45a4fb6a4b3a9f51'}]},
#   'public': True,
#   'created_at': '2025-01-24T01:36:14Z'},
#  {'id': '45867814073',
#   'type': 'PushEvent',
#   'actor': {'id': 125607205,
#    'login': 'spenceratwatson',
#    'display_login': 'spenceratwatson',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/spenceratwatson',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/125607205?'},
#   'repo': {'id': 691252417,
#    'name': 'Watson-Creative/wc-tracking-code-injector',
#    'url': 'https://api.github.com/repos/Watson-Creative/wc-tracking-code-injector'},
#   'payload': {'repository_id': 691252417,
#    'push_id': 22288716889,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '3d91664711281f209efa8faa1cf44fc25dde27ac',
#    'before': 'e5a08f7c1e23262e41fb25cbc72e4eab03a45608',
#    'commits': [{'sha': '3d91664711281f209efa8faa1cf44fc25dde27ac',
#      'author': {'email': 'spencer@watsoncreative.com',
#       'name': 'Spencer Thayer'},
#      'message': 'feat: Update version to 2.4.10\n\nUpdate the version number in README.md and wc-tracking-code-injector.php to 2.4.10, reflecting the latest release of the WC Tracking Code Injector plugin.',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Watson-Creative/wc-tracking-code-injector/commits/3d91664711281f209efa8faa1cf44fc25dde27ac'}]},
#   'public': True,
#   'created_at': '2025-01-24T01:36:14Z',
#   'org': {'id': 34494673,
#    'login': 'Watson-Creative',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/Watson-Creative',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/34494673?'}},
#  {'id': '45867814074',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 467315450,
#    'name': 'SteveMoreira/SteveMoreira',
#    'url': 'https://api.github.com/repos/SteveMoreira/SteveMoreira'},
#   'payload': {'repository_id': 467315450,
#    'push_id': 22288716943,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/output',
#    'head': '20b435c46c9e13058032e671c0d4e662fa8c2c35',
#    'before': '9d96010a3b2465727fd6b83471fd6b83aa47bbba',
#    'commits': [{'sha': '20b435c46c9e13058032e671c0d4e662fa8c2c35',
#      'author': {'email': '41898282+github-actions[bot]@users.noreply.github.com',
#       'name': 'github-actions[bot]'},
#      'message': 'Deploy to GitHub pages',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/SteveMoreira/SteveMoreira/commits/20b435c46c9e13058032e671c0d4e662fa8c2c35'}]},
#   'public': True,
#   'created_at': '2025-01-24T01:36:14Z'},
#  {'id': '45867814064',
#   'type': 'PushEvent',
#   'actor': {'id': 93323965,
#    'login': 'supervpnops',
#    'display_login': 'supervpnops',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/supervpnops',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/93323965?'},
#   'repo': {'id': 520882691,
#    'name': 'supervpnops/sl_for_ios_greenapp',
#    'url': 'https://api.github.com/repos/supervpnops/sl_for_ios_greenapp'},
#   'payload': {'repository_id': 520882691,
#    'push_id': 22288716887,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '9415a6a070667b1577e256ba22a45c6578d69911',
#    'before': 'fad750ebaecfe1839dee83669fa39f0ee4a2e6e7',
#    'commits': [{'sha': '9415a6a070667b1577e256ba22a45c6578d69911',
#      'author': {'email': '93323965+supervpnops@users.noreply.github.com',
#       'name': 'supervpnops'},
#      'message': 'green_ios',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/supervpnops/sl_for_ios_greenapp/commits/9415a6a070667b1577e256ba22a45c6578d69911'}]},
#   'public': True,
#   'created_at': '2025-01-24T01:36:14Z'},
#  {'id': '45867814071',
#   'type': 'PushEvent',
#   'actor': {'id': 77461588,
#    'login': 'NOTMODDER',
#    'display_login': 'NOTMODDER',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/NOTMODDER',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/77461588?'},
#   'repo': {'id': 916714811,
#    'name': 'NOTMODDER/tiny-glimmer.nvim',
#    'url': 'https://api.github.com/repos/NOTMODDER/tiny-glimmer.nvim'},
#   'payload': {'repository_id': 916714811,
#    'push_id': 22288716901,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'd7f20eca3876f8e925da7afdbf12ebe15e64fc22',
#    'before': '6fa4c577068adfadf30d9629cc91ad6f1104a9ec',
#    'commits': [{'sha': 'd7f20eca3876f8e925da7afdbf12ebe15e64fc22',
#      'author': {'email': '77461588+NOTMODDER@users.noreply.github.com',
#       'name': 'NOTMODDER'},
#      'message': 'Commit',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/NOTMODDER/tiny-glimmer.nvim/commits/d7f20eca3876f8e925da7afdbf12ebe15e64fc22'}]},
#   'public': True,
#   'created_at': '2025-01-24T01:36:14Z'},
#  {'id': '45867814061',
#   'type': 'PushEvent',
#   'actor': {'id': 22048631,
#    'login': 'nijiinfrastructure',
#    'display_login': 'nijiinfrastructure',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/nijiinfrastructure',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/22048631?'},
#   'repo': {'id': 921452326,
#    'name': 'nijiinfrastructure/Niji-AI-Terminal',
#    'url': 'https://api.github.com/repos/nijiinfrastructure/Niji-AI-Terminal'},
#   'payload': {'repository_id': 921452326,
#    'push_id': 22288716917,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '39c7b9d77727b60a39598bd0cc261220263c367b',
#    'before': 'd80b73abe6e44dd5efb53ee11fc43849ab37c396',
#    'commits': [{'sha': '39c7b9d77727b60a39598bd0cc261220263c367b',
#      'author': {'email': '22048631+nijiinfrastructure@users.noreply.github.com',
#       'name': 'niji'},
#      'message': 'Update README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/nijiinfrastructure/Niji-AI-Terminal/commits/39c7b9d77727b60a39598bd0cc261220263c367b'}]},
#   'public': True,
#   'created_at': '2025-01-24T01:36:14Z'},
#  {'id': '45867814047',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 462360262,
#    'name': 'diegocarloni/diegocarloni',
#    'url': 'https://api.github.com/repos/diegocarloni/diegocarloni'},
#   'payload': {'repository_id': 462360262,
#    'push_id': 22288716941,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/output',
#    'head': '20b435c46c9e13058032e671c0d4e662fa8c2c35',
#    'before': 'b4ce71b21952fef2a2738cb5f8dfc0a192f46023',
#    'commits': [{'sha': '20b435c46c9e13058032e671c0d4e662fa8c2c35',
#      'author': {'email': '41898282+github-actions[bot]@users.noreply.github.com',
#       'name': 'github-actions[bot]'},
#      'message': 'Deploy to GitHub pages',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/diegocarloni/diegocarloni/commits/20b435c46c9e13058032e671c0d4e662fa8c2c35'}]},
#   'public': True,
#   'created_at': '2025-01-24T01:36:14Z'},
#  {'id': '45867814057',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 443137291,
#    'name': 'MertKulac/MertKulac',
#    'url': 'https://api.github.com/repos/MertKulac/MertKulac'},
#   'payload': {'repository_id': 443137291,
#    'push_id': 22288716900,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/output',
#    'head': 'dffa478ba95402b737bbdf7f91011b419783424f',
#    'before': 'fabec14664b5dc504cea0bbab0d8015fae44f667',
#    'commits': [{'sha': 'dffa478ba95402b737bbdf7f91011b419783424f',
#      'author': {'email': '41898282+github-actions[bot]@users.noreply.github.com',
#       'name': 'github-actions[bot]'},
#      'message': 'Deploy to GitHub pages',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/MertKulac/MertKulac/commits/dffa478ba95402b737bbdf7f91011b419783424f'}]},
#   'public': True,
#   'created_at': '2025-01-24T01:36:14Z'},
#  {'id': '45867814045',
#   'type': 'PushEvent',
#   'actor': {'id': 192595923,
#    'login': 'karimzynera',
#    'display_login': 'karimzynera',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/karimzynera',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/192595923?'},
#   'repo': {'id': 917245168,
#    'name': 'karimzynera/make-backup',
#    'url': 'https://api.github.com/repos/karimzynera/make-backup'},
#   'payload': {'repository_id': 917245168,
#    'push_id': 22288716933,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '3eec5c93edcc17f8b24c955efe1f18d0eccb07c0',
#    'before': 'abb7fe3532c7c6c694cc5471773267c4975c5ad9',
#    'commits': [{'sha': '3eec5c93edcc17f8b24c955efe1f18d0eccb07c0',
#      'author': {'email': 'karim@zynera.ai', 'name': 'Karim'},
#      'message': '"MA C05 U01" last edited by Karim El Kassas @ 2024-12-22T16:21:09.442Z',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/karimzynera/make-backup/commits/3eec5c93edcc17f8b24c955efe1f18d0eccb07c0'}]},
#   'public': True,
#   'created_at': '2025-01-24T01:36:14Z'},
#  {'id': '45867814046',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 437812294,
#    'name': 'developerbunyodbek/developerbunyodbek',
#    'url': 'https://api.github.com/repos/developerbunyodbek/developerbunyodbek'},
#   'payload': {'repository_id': 437812294,
#    'push_id': 22288716936,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/output',
#    'head': '20b435c46c9e13058032e671c0d4e662fa8c2c35',
#    'before': '08f5694566494e8e583517d8800787ccbbdbbd35',
#    'commits': [{'sha': '20b435c46c9e13058032e671c0d4e662fa8c2c35',
#      'author': {'email': '41898282+github-actions[bot]@users.noreply.github.com',
#       'name': 'github-actions[bot]'},
#      'message': 'Deploy to GitHub pages',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/developerbunyodbek/developerbunyodbek/commits/20b435c46c9e13058032e671c0d4e662fa8c2c35'}]},
#   'public': True,
#   'created_at': '2025-01-24T01:36:14Z'},
#  {'id': '45867814042',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 745793359,
#    'name': 'dninc2/BXVCSD',
#    'url': 'https://api.github.com/repos/dninc2/BXVCSD'},
#   'payload': {'repository_id': 745793359,
#    'push_id': 22288716947,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '6f8860de5f77d09305b41867f9766716ee61676a',
#    'before': 'cfa015a98cda46740591272d06f7219fd79071c2',
#    'commits': [{'sha': '6f8860de5f77d09305b41867f9766716ee61676a',
#      'author': {'email': 'theipersasourmy@mail.com', 'name': 'dninc2'},
#      'message': 'a commit a day keeps your girlfriend away',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/dninc2/BXVCSD/commits/6f8860de5f77d09305b41867f9766716ee61676a'}]},
#   'public': True,
#   'created_at': '2025-01-24T01:36:14Z'},
#  {'id': '45867814038',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 744109638,
#    'name': 'veryCrunchy/veryCrunchy',
#    'url': 'https://api.github.com/repos/veryCrunchy/veryCrunchy'},
#   'payload': {'repository_id': 744109638,
#    'push_id': 22288716890,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '9f5daed09d30e73b1361b09b35dfacbaaaddc305',
#    'before': '050df6678631d81b466706240ac1455e7bd36ae9',
#    'commits': [{'sha': '9f5daed09d30e73b1361b09b35dfacbaaaddc305',
#      'author': {'email': '41898282+github-actions[bot]@users.noreply.github.com',
#       'name': 'github-actions[bot]'},
#      'message': 'Updated waka-readme graph with new metrics',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/veryCrunchy/veryCrunchy/commits/9f5daed09d30e73b1361b09b35dfacbaaaddc305'}]},
#   'public': True,
#   'created_at': '2025-01-24T01:36:14Z'},
#  {'id': '45867814031',
#   'type': 'PushEvent',
#   'actor': {'id': 194290337,
#    'login': 'Anirudhsrini97',
#    'display_login': 'Anirudhsrini97',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Anirudhsrini97',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/194290337?'},
#   'repo': {'id': 920901597,
#    'name': 'Anirudhsrini97/demo-infras',
#    'url': 'https://api.github.com/repos/Anirudhsrini97/demo-infras'},
#   'payload': {'repository_id': 920901597,
#    'push_id': 22288716866,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '646d5e3b263a625f396d0afcf622fa0293a840da',
#    'before': 'e4c6a24df43e347bf7e8a39f5f66b9d7b9362a72',
#    'commits': [{'sha': '646d5e3b263a625f396d0afcf622fa0293a840da',
#      'author': {'email': 'srinivasan.andyy@gmail.com', 'name': 'Anirudh'},
#      'message': 'Fix variable escape character',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Anirudhsrini97/demo-infras/commits/646d5e3b263a625f396d0afcf622fa0293a840da'}]},
#   'public': True,
#   'created_at': '2025-01-24T01:36:14Z'},
#  {'id': '45867814020',
#   'type': 'PushEvent',
#   'actor': {'id': 72382663,
#    'login': '1domybest',
#    'display_login': '1domybest',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/1domybest',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/72382663?'},
#   'repo': {'id': 920940591,
#    'name': '1domybest/react_typescript_pratice',
#    'url': 'https://api.github.com/repos/1domybest/react_typescript_pratice'},
#   'payload': {'repository_id': 920940591,
#    'push_id': 22288716864,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'e0cff338a27763b3ad7f33d1d713bae5124873f5',
#    'before': 'bbe849c5c86abdc20e4b5e0521613cca73a79c11',
#    'commits': [{'sha': 'e0cff338a27763b3ad7f33d1d713bae5124873f5',
#      'author': {'email': '72382663+1domybest@users.noreply.github.com',
#       'name': 'OTIS'},
#      'message': '.\n\n.',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/1domybest/react_typescript_pratice/commits/e0cff338a27763b3ad7f33d1d713bae5124873f5'}]},
#   'public': True,
#   'created_at': '2025-01-24T01:36:14Z'},
#  {'id': '45867814044',
#   'type': 'DeleteEvent',
#   'actor': {'id': 47325237,
#    'login': 'cbhanni',
#    'display_login': 'cbhanni',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/cbhanni',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/47325237?'},
#   'repo': {'id': 858938986,
#    'name': 'cbhanni/AI-Ethics',
#    'url': 'https://api.github.com/repos/cbhanni/AI-Ethics'},
#   'payload': {'ref': 'cbhanni-patch-2',
#    'ref_type': 'branch',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2025-01-24T01:36:14Z'},
#  {'id': '45867814040',
#   'type': 'CreateEvent',
#   'actor': {'id': 108731205,
#    'login': 'csarthur',
#    'display_login': 'csarthur',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/csarthur',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/108731205?'},
#   'repo': {'id': 921458532,
#    'name': 'cu-ecen-aeld/assignment-9-csarthur',
#    'url': 'https://api.github.com/repos/cu-ecen-aeld/assignment-9-csarthur'},
#   'payload': {'ref': 'main',
#    'ref_type': 'branch',
#    'master_branch': 'main',
#    'description': 'assignment-9-csarthur created by GitHub Classroom',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2025-01-24T01:36:14Z',
#   'org': {'id': 49594950,
#    'login': 'cu-ecen-aeld',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/cu-ecen-aeld',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49594950?'}}]

# %%
r = requests.get('https://api.github.com/versions')
r.status_code
# Out:
# 200

# %%
r.json()
# Out:
# ['2022-11-28']

# %%
import requests

r = requests.get('https://api.github.com/users/millenagena')
r
# Out:
# <Response [200]>

# %%
r.status_code
# Out:
# 200

# %%
r.json()
# Out:
# {'login': 'millenagena',
#  'id': 69437878,
#  'node_id': 'MDQ6VXNlcjY5NDM3ODc4',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/69437878?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/millenagena',
#  'html_url': 'https://github.com/millenagena',
#  'followers_url': 'https://api.github.com/users/millenagena/followers',
#  'following_url': 'https://api.github.com/users/millenagena/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/millenagena/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/millenagena/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/millenagena/subscriptions',
#  'organizations_url': 'https://api.github.com/users/millenagena/orgs',
#  'repos_url': 'https://api.github.com/users/millenagena/repos',
#  'events_url': 'https://api.github.com/users/millenagena/events{/privacy}',
#  'received_events_url': 'https://api.github.com/users/millenagena/received_events',
#  'type': 'User',
#  'user_view_type': 'public',
#  'site_admin': False,
#  'name': 'Millena Gená',
#  'company': None,
#  'blog': '',
#  'location': 'Minas Gerais, Brazil',
#  'email': None,
#  'hireable': None,
#  'bio': None,
#  'twitter_username': None,
#  'public_repos': 27,
#  'public_gists': 0,
#  'followers': 132,
#  'following': 31,
#  'created_at': '2020-08-09T22:03:04Z',
#  'updated_at': '2024-10-09T17:43:29Z'}

# %%
r.json()['name']
# Out:
# 'Millena Gená'

# %%
r.json()['login']
# Out:
# 'millenagena'

# %%
r.json()['public_repos']
# Out:
# 27

# %%
r.json()['created_at']
# Out:
# '2020-08-09T22:03:04Z'
